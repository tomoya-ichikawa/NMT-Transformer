# %% [markdown]
# <a href="https://colab.research.google.com/github/tomoya-ichikawa/NMT-Transformer/blob/main/transformer_ver2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
from torch import nn, optim
from torch.utils.data import(Dataset, DataLoader, TensorDataset)
import torch.nn as nn
import math
from torch.autograd import Variable
import tqdm
import re
import collections
import itertools
import numpy as np
import copy
import torch.nn.functional as F

# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def normalizeString(s,l):
    if s == l[0]:
      s = s.lower().strip()
   
  
    s = re.sub(r"([.!?])", r" \1", s)
    #s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
    return s

def build_vocab(tokens):
  counts = collections.Counter(tokens)
  sorted_counts = sorted(counts.items(), key=lambda c: c[1], reverse=True)
  word_list = ["<PAD>","<SOS>", "<EOS>", "<UNK>"]+[x[0] for x in sorted_counts]
  word_dict = dict((w, i) for i, w in enumerate(word_list))
  return word_list, word_dict

def word2tensor(words, word_dict, max_len, trgg=False, padding=0):
  if trgg:
    words = ["<SOS>"] + words
  words = [word_dict.get(w, 3) for w in words]
  seq_len = len(words)
  if seq_len < max_len:
    words = words + [padding]*(max_len-seq_len)
  return torch.tensor(words, dtype=torch.int64), seq_len
def word2ltensor(words, word_dict, max_len, trgg=False, padding=0):
  if trgg:
    words =  words +["<EOS>"]
  words = [word_dict.get(w, 3) for w in words]
  seq_len = len(words)
  if seq_len < max_len:
    words = words + [padding]*(max_len-seq_len)
  return torch.tensor(words, dtype=torch.int64), seq_len

# %%
class MyDataset(torch.utils.data.Dataset):

  def __init__(self, path, max_len=17, test=False):
    lines = open(path, encoding='utf-8').read().strip().split('\n')
    pairs = [[normalizeString(s,l) for s in l.split('\t')] for l in lines]

    src = [p[0] for p in pairs]
    src = [l.split(" ") for l in src]
    trg = [p[1] for p in pairs]
    trg = [l.split(" ") for l in trg]
    if test:
      self.src_word_list, self.src_word_dict = train_data.src_word_list, train_data.src_word_dict
      self.trg_word_list, self.trg_word_dict = train_data.trg_word_list, train_data.trg_word_dict
    #リストを要素として持つリスト（2次元リスト）を平坦化する
    else:
      self.src_word_list,self.src_word_dict = build_vocab(itertools.chain.from_iterable(src))
      self.trg_word_list,self.trg_word_dict = build_vocab(itertools.chain.from_iterable(trg))

    self.src_data = [word2tensor(words, self.src_word_dict, max_len) for words in src]
    self.trg_data = [word2tensor(words, self.trg_word_dict, max_len, trgg=True) for words in trg]
    self.trg_label = [word2ltensor(words, self.trg_word_dict, max_len, trgg=True, padding = -100) for words in trg]

  def __len__(self):
    return len(self.trg_data)
  def __getitem__(self, idx):
    src, lsrc = self.src_data[idx]
    trg, ltrg = self.trg_data[idx]
    label, llabel = self.trg_label[idx]
    return src, lsrc, trg, ltrg,label, llabel

# %%
batch_size = 256
max_len =30
path = "drive/MyDrive/Colab-Notebooks/eng-ja.txt"
path2 = "drive/MyDrive/Colab-Notebooks/eng-ja2.txt"
train_data = MyDataset(path, max_len=max_len)
train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True, num_workers=4)
test_data = MyDataset(path2, max_len=max_len, test=True)
test_loader = DataLoader(test_data)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
class Embedder(nn.Module):
  def __init__(self, vocab_size, d_model):
    super().__init__()
    self.embed = nn.Embedding(vocab_size, d_model, padding_idx=0)
  def forward(self, x):
    return self.embed(x)

# %%
class PositionalEncoder(nn.Module):
    def __init__(self, d_model, max_seq_len = 80, dropout=0.1):
        super().__init__()
        self.d_model = d_model
        self.dropout = nn.Dropout(dropout)
        pe = torch.zeros(max_seq_len, d_model)
        device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        pe = pe.to(device)
        for pos in range(max_seq_len):
            for i in range(0, d_model, 2):
                pe[pos, i] = \
                math.sin(pos/ (10000 ** ((2 * i)/d_model)))
                pe[pos, i+1] = \
                math.cos(pos/(10000**((2*(i+1))/d_model)))
        
        self.pe = pe.unsqueeze(0)
        self.pe.requires_grad = False
        
    def forward(self, x):
        seq_len = x.size(1)
        
        ret = math.sqrt(self.d_model)*x + self.pe[:,:seq_len,:]
        return self.dropout(x)

# %%
def get_clones(module, N):
    return nn.ModuleList([copy.deepcopy(module) for i in range(N)])

# %%
class MultiHeadAttention(nn.Module):
    def __init__(self, heads, d_model):
        super().__init__()
        self.d_model = d_model
        self.d_k = d_model // heads
        self.h = heads
        self.h_attention = get_clones(Attention(d_model, self.d_k), heads)
        self.out = nn.Linear(d_model, d_model)
    
    def forward(self, q, k, v, mask=None, trg_masked=False):
        for i in range(self.h):
            if i==0:
                concat = self.h_attention[0](q, k, v, mask, trg_masked)
            else:
                h_atten = self.h_attention[i](q, k, v, mask, trg_masked)
                concat = torch.cat((concat, h_atten), 2)
    
        output = self.out(concat)
        return output

# %%
class Attention(nn.Module):
    def __init__(self, d_model, d_k, dropout=0.1):
        super().__init__()
        self.q_linear = nn.Linear(d_model, d_k)
        self.v_linear = nn.Linear(d_model, d_k)
        self.k_linear = nn.Linear(d_model, d_k)
        self.nopeak_mask = torch.tensor(np.triu(np.ones((max_len, max_len)), k=1).astype('uint8')).unsqueeze(0).to(device)
        self.d_k = d_k
        self.dropout = nn.Dropout(dropout)
    
    def forward(self, q, k, v, pad_mask=None,trg_masked=False):
        k = self.k_linear(k)
        q = self.q_linear(q)
        v = self.v_linear(v)

        weights = torch.matmul(q, k.transpose(1,2)) / math.sqrt(self.d_k)
        if pad_mask is not None:
            pad_mask = pad_mask.unsqueeze(1)
            weights = weights.masked_fill(pad_mask == 0, -1e9)
        
        if trg_masked:
            weights = weights.masked_fill(self.nopeak_mask == 1, -1e9)
            
        normlized_weights =  F.softmax(weights, dim=-1)
        normlized_weights = self.dropout(normlized_weights)
        output = torch.matmul(normlized_weights, v)

        return output

# %%
class FeedForward(nn.Module):
    def __init__(self, d_model, d_ff=1024, dropout=0.1):
        super().__init__()
        self.linear_1 = nn.Linear(d_model, d_ff)
        self.dropout = nn.Dropout(dropout)
        self.linear_2 = nn.Linear(d_ff, d_model)
    
    def forward(self, x):
        x = self.linear_1(x)
        x = self.dropout(F.relu(x))
        x = self.linear_2(x)
        return x

# %%
class TransformerEncLayer(nn.Module):
    def __init__(self, d_model, head, dropout=0.1):
        super().__init__()
        self.norm_1 = nn.LayerNorm(d_model)
        self.norm_2 = nn.LayerNorm(d_model)
        self.multi_attn = MultiHeadAttention(head, d_model)
        self.ff = FeedForward(d_model)
        self.dropout_1 = nn.Dropout(dropout)
        self.dropout_2 = nn.Dropout(dropout)
    
    def forward(self, x, mask=None):

        x_attn = self.multi_attn(x, x, x, mask)
        x = x + self.dropout_1(x_attn)
        x_norm = self.norm_1(x)

        output = x_norm + self.dropout_2(self.ff(x_norm))
        output = self.norm_2(output)
        return output

# %%
class TransformerDecLayer(nn.Module):
    def __init__(self, d_model, head, dropout=0.1):
        super().__init__()
        self.norm_1 = nn.LayerNorm(d_model)
        self.norm_2 = nn.LayerNorm(d_model)
        self.norm_3 = nn.LayerNorm(d_model)
        self.multi_attn = MultiHeadAttention(head, d_model)
        self.src_trg_attn = MultiHeadAttention(head, d_model)
        self.ff = FeedForward(d_model)
        self.dropout_1 = nn.Dropout(dropout)
        self.dropout_2 = nn.Dropout(dropout)
        self.dropout_3 = nn.Dropout(dropout)
    
    def forward(self, y, memory, src_mask=None, trg_mask=None, masked=False):
        
        y_attn = self.multi_attn(y, y, y, trg_mask, trg_masked=masked)
        y = y + self.dropout_1(y_attn)
        y_norm = self.norm_1(y)

        y_attn = self.src_trg_attn(y_norm, memory, memory, src_mask)
        y2 = y_norm + self.dropout_2(y_attn)
        y_norm2 = self.norm_2(y2)

        output = y_norm2 + self.dropout_3(self.ff(y_norm2))
        output = self.norm_3(output)
        return output

# %%
class TransformerEncoder(nn.Module):
    def __init__(self, vocab_size, d_model, head, num_layer):
        super().__init__()
        self.embedding = Embedder(vocab_size, d_model)
        self.pos_enc = PositionalEncoder(d_model, max_len)
        self.num_layer = num_layer
        self.transformerlayer = get_clones(TransformerEncLayer(d_model, head), num_layer)

    def forward(self, x, mask=None):
        x = self.embedding(x)
        x = self.pos_enc(x)

        for i in range(self.num_layer):
            x = self.transformerlayer[i](x, mask)
        return x

# %%
class TransformerDecoder(nn.Module):
    def __init__(self, vocab_size, d_model, head, num_layer):
        super().__init__()
        self.embedding = Embedder(vocab_size, d_model)
        self.pos_enc = PositionalEncoder(d_model, max_len)
        self.num_layer = num_layer
        self.transformerlayer = get_clones(TransformerDecLayer(d_model, head), num_layer)

    def forward(self, y, memory, src_mask=None, trg_mask=None, masked=False):
        
        y = self.embedding(y)
        y = self.pos_enc(y)

        for i in range(self.num_layer):
            y = self.transformerlayer[i](y, memory, src_mask, trg_mask, masked)

        return y

# %%
class Transformer(nn.Module):
    def __init__(self, src_vocab_size, trg_vocab_size, d_model, head, num_layer):
        super().__init__()
        self.encoder = TransformerEncoder(src_vocab_size, d_model, head, num_layer)
        self.decoder = TransformerDecoder(trg_vocab_size, d_model, head, num_layer)
        self.linear = nn.Linear(d_model, trg_vocab_size)
    
    def forward(self, src, trg, src_mask=None, trg_mask=None, masked=False):
     
        memory = self.encoder(src, src_mask)
        out = self.decoder(trg, memory, src_mask, trg_mask, masked)
        out = self.linear(out)
        return out

# %%
class LabelSmoothingLoss(nn.Module):
    def __init__(self, classes, smoothing=0.0, dim=-1):
        super(LabelSmoothingLoss, self).__init__()
        self.confidence = 1.0 - smoothing
        self.smoothing = smoothing
        self.cls = classes
        self.dim = dim

    def forward(self, pred, target, device="cpu"):
        pred = pred.log_softmax(dim=self.dim).to(device)
        
        with torch.no_grad():
            # true_dist = pred.data.clone()
            true_dist = torch.zeros_like(pred).to(device)
            
            true_dist.fill_(self.smoothing / (self.cls - 1))
           
            
            true_dist.scatter_(1, target.data.unsqueeze(1), self.confidence)
            
        return torch.mean(torch.sum(-true_dist * pred, dim=self.dim))

# %%
d_model = 512
heads = 8
N = 6
warmup_steps = 4000
device = "cuda:0"
step_num = 0
src_vocab_size = len(train_data.src_word_list)
trg_vocab_size = len(train_data.trg_word_list)

model = Transformer(src_vocab_size, trg_vocab_size, d_model, heads, N)

for p in model.parameters():
    if p.dim() > 1:
       nn.init.xavier_uniform_(p)
model.to(device)

optim = torch.optim.Adam(model.parameters(), lr=0.0001, betas=(0.9, 0.98), eps=1e-9)
#optimizer = ScheduledOptim(torch.optim.Adam(model.parameters(), betas=(0.9, 0.98), eps=1e-09),2.0, d_model, n_warmup_steps)
#loss_f = LabelSmoothingLoss(trg_vocab_size, smoothing=0.1)

loss_f = nn.CrossEntropyLoss()

# %%
def to2D(x):
  shapes = x.shape
  return x.reshape(shapes[0]*shapes[1], -1)

# %%
from statistics import mean

model.train()
pad_idx = 0
for epoc in range(40):
    losses = []
    for x, lx, y, ly, label, llabel in train_loader:
        step_num +=1
        src_mask = (x != pad_idx)
        trg_mask = (y != pad_idx)
        x, y, label = x.to(device), y.to(device), label.to(device)
        src_mask, trg_mask = src_mask.to(device), trg_mask.to(device)
        
        output = model(x, y, src_mask, trg_mask, masked=True)
        loss = loss_f(to2D(output), to2D(label).squeeze())
        optim.zero_grad()
        loss.backward()
        optim.step()
        losses.append(loss.item())
        

    print(epoc, mean(losses))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# 0 5.486537171869862
# 1 4.126660479574787
# 2 3.664931886050166
# 3 3.3192857662025763
# 4 2.957549108534443
# 5 2.6571999496343186
# 6 2.4359048957727394
# 7 2.2563987349977297
# 8 2.11081487001205
# 9 1.978108137845993
# 10 1.8661786840886485
# 11 1.7637063228354162
# 12 1.6703545475492672
# 13 1.5887905055162859
# 14 1.5105626315486675
# 15 1.4374683091835099
# 16 1.3720791826442795
# 17 1.3107740854730412
# 18 1.2520836281533143
# 19 1.1967053279584767
# 20 1.146057527284233
# 21 1.0974252111449534
# 22 1.0506788598639625
# 23 1.0068632419012031
# 24 0.9640755580396069
# 25 0.9264607581557059
# 26 0.8881586534636361
# 27 0.8532327991359088
# 28 0.8163929678955857
# 29 0.7837950663298977
# 30 0.753468353833471
# 31 0.723215387487898
# 32 0.6940340603492698
# 33 0.668218836796527
# 34 0.6390716494346151
# 35 0.6130103234733854
# 36 0.5907072788294481
# 37 0.5669119802056527
# 38 0.5434364706886058
# 39 0.5241334439844502

# %%
def translate(input_str, input_len, model, s_mask, max_len=20, device = "cpu"):
  sos_inputs = torch.tensor([[1]], dtype=torch.int64)
  input_str = input_str.to(device)
  sos_inputs = sos_inputs.to(device)
  s_mask = s_mask.to(device)
  z = sos_inputs
  results = []
  
  for i in range(max_len):
    output = model(input_str, z, s_mask)
    output = output[:, i, :]
    pred = output.detach().view(-1).max(0)[1]
    if pred.item()==2:
      break
    results.append(pred.item())

    z = torch.cat((z,pred.unsqueeze(0).unsqueeze(0)), 1)

  return " ".join(train_data.trg_word_list[i] for i in results)

# %%
model.eval()
ptrgs=[]
with torch.no_grad():
  for x, lx, y, ly, label, llabel in test_loader:
    src_mask = (x != pad_idx)
    ptrg = translate(x, lx, model,src_mask, device="cuda:0")
    y = y[:,1:ly]
    w = " ".join(train_data.trg_word_list[i] for i in y.squeeze())
    print(ptrg)
    ptrgs.append((ptrg, w))

# %%
for pred, refer in ptrgs:
    print("翻訳文："+pred)
    print("参照訳："+refer)
    print("")
# Out:
# 翻訳文：at fact that they didn 't understand it  .
# 参照訳：they finally acknowledged it as true  .
#
# 翻訳文：he was not good at swimming  .
# 参照訳：he didn 't care for swimming  .
#
# 翻訳文：he is less kind than her sister  .
# 参照訳：he is no less kind than his sister  .
#
# 翻訳文：you must come back before  .
# 参照訳：you must be back before ten  .
#
# 翻訳文：i hope of success
# 参照訳：break a leg  .
#
# 翻訳文：she is our house  .
# 参照訳：she lives next door to us  .
#
# 翻訳文：i am looking forward to you  .
# 参照訳：i 'm about to tell you the answer  .
#
# 翻訳文：i know nothing for living  .
# 参照訳：i 'm a person who lives for the moment  .
#
# 翻訳文：i 'd like a game  .
# 参照訳：we have this game on ice  .
#
# 翻訳文：do such a reason you have told  .
# 参照訳：will you give me your reasons for doing this  ?
#
# 翻訳文：she likes the teacher  .
# 参照訳：she likes the teacher  .
#
# 翻訳文：that 's business  .
# 参照訳：it 's business  .
#
# 翻訳文：these shoes will be old  .
# 参照訳：these shoes will last you two years  .
#
# 翻訳文：he left the place in his own place  .
# 参照訳：he made his son attend the meeting in his place  .
#
# 翻訳文：be sure to tell me  .
# 参照訳：give your argument against going  .
#
# 翻訳文：while we are working out  .
# 参照訳：at the end of a working day everybody is in a hurry to get home  .
#
# 翻訳文：she had an face to look  .
# 参照訳：i was unable to look her in the face  .
#
# 翻訳文：every day i go to church  .
# 参照訳：some people go to church on sunday morning  .
#
# 翻訳文：i must watch the day  .
# 参照訳：i must put my watch forward two minutes  .
#
# 翻訳文：that is the boy i saw yesterday  .
# 参照訳：that is the boy i saw yesterday  .
#
# 翻訳文：it is ten years to wait  .
# 参照訳：ten years is a long time to wait  .
#
# 翻訳文：i met him in tokyo  .
# 参照訳：i met him in tokyo by chance  .
#
# 翻訳文：i often go swimming in the river  .
# 参照訳：i often go swimming in the river  .
#
# 翻訳文：he called for help  .
# 参照訳：he called out for help  .
#
# 翻訳文：he broke out of the child  .
# 参照訳：he rescued the child from the fire  .
#
# 翻訳文：i cannot agree to his proposal  .
# 参照訳：i cannot agree to his proposal  .
#
# 翻訳文：we 've heard over the times  .
# 参照訳：we read the letter again and again  .
#
# 翻訳文：i 'm glad to see you  .
# 参照訳：i 'm happy to see you  .
#
# 翻訳文：take your father  .
# 参照訳：ask your dad to help you  .
#
# 翻訳文：they made the proposal  .
# 参照訳：they adopted the proposal  .
#
# 翻訳文：i feel in a good place  .
# 参照訳：i feel good in a special way  .
#
# 翻訳文：he had seen it  .
# 参照訳：nobody has seen him ever since  .
#
# 翻訳文：she had seen times  .
# 参照訳：she has seen better days  .
#
# 翻訳文：please pass the boys  .
# 参照訳：please pass it to the other boys  .
#
# 翻訳文：i remember my name  .
# 参照訳：i still bear his name in mind  .
#
# 翻訳文：let 's marry  .
# 参照訳：i want to marry you  .
#
# 翻訳文：they meet sometimes  .
# 参照訳：we see them on occasion  .
#
# 翻訳文：the earth goes  .
# 参照訳：the earth <UNK>  .
#
# 翻訳文：i want which better  .
# 参照訳：tell me which you want  .
#
# 翻訳文：i wish he was in the place  .
# 参照訳：i wish i knew where he was  !
#
# 翻訳文：i had an examination last examination  .
# 参照訳：we took an examination in math last week  .
#
# 翻訳文：could you be able to be a way  .
# 参照訳：check , please  .
#
# 翻訳文：i heard nothing ,  .
# 参照訳：i listened , but i heard nothing  .
#
# 翻訳文：she didn 't marry  .
# 参照訳：she did not marry the man  .
#
# 翻訳文：he doesn 't read much  .
# 参照訳：he doesn 't read many books  .
#
# 翻訳文：she is not in her sense
# 参照訳：she doesn 't have any <UNK>  .
#
# 翻訳文：it 's very hot  .
# 参照訳：in the summer , it 's very humid  .
#
# 翻訳文：he wrote a pen  .
# 参照訳：he made me write the letter with a pen  .
#
# 翻訳文：he was tired of reading  .
# 参照訳：he got tired of reading  .
#
# 翻訳文：write your address  .
# 参照訳：put down your name and address here  .
#
# 翻訳文：she played well  .
# 参照訳：she played the piano well enough  .
#
# 翻訳文：i don 't need to come  .
# 参照訳：i 'm still waiting for my order  .
#
# 翻訳文：there are a lot of books in this library  .
# 参照訳：there are a great many books in this library  .
#
# 翻訳文：you should make good  .
# 参照訳：you should avail yourself of every opportunity  .
#
# 翻訳文：how many school are there in your town  ?
# 参照訳：how many schools are there in your city  ?
#
# 翻訳文：i don 't like any music  .
# 参照訳：i don 't like sad movies  .
#
# 翻訳文：she was very angry with me  .
# 参照訳：she was very angry with me when i forgot the appointment  .
#
# 翻訳文：we are enough to know  .
# 参照訳：people of your age often have this problem  .
#
# 翻訳文：i like your car  .
# 参照訳：i like your car  .
#
# 翻訳文：she stood across the river  .
# 参照訳：she stood looking at a boat on the river  .
#
# 翻訳文：i will come , either  .
# 参照訳：whether he comes or not , i 'll go  .
#
# 翻訳文：i don 't get up early  .
# 参照訳：i don 't get up as early as my mother  .
#
# 翻訳文：any flowers will take  .
# 参照訳：any flower will do , so long as it is red  .
#
# 翻訳文：don 't forget to join me  .
# 参照訳：don 't forget to add me in  .
#
# 翻訳文：you 're in common  .
# 参照訳：you are the only one  .
#
# 翻訳文：i must leave the point  .
# 参照訳：i stick to the point  .
#
# 翻訳文：please come on monday  .
# 参照訳：i 'll be here by monday  .
#
# 翻訳文：she is in the happy  .
# 参照訳：she is the happiest in her class  .
#
# 翻訳文：what an beautiful sky is  !
# 参照訳：how beautiful the rising sun is  !
#
# 翻訳文：there is less precious  .
# 参照訳：nothing is so precious as time  .
#
# 翻訳文：you need not come so early  .
# 参照訳：you did not need to come so early  .
#
# 翻訳文：i found a question  .
# 参照訳：i had some questions and raised my hand  .
#
# 翻訳文：she is satisfied with the life  .
# 参照訳：she expressed satisfaction with her life  .
#
# 翻訳文：the concert broke up last  .
# 参照訳：it was around eight last night when the meeting broke up  .
#
# 翻訳文：life is the world  .
# 参照訳：the life of a person is a <UNK> thing  .
#
# 翻訳文：don 't like your own money  .
# 参照訳：don 't raise my hopes like that  .
#
# 翻訳文：they were slow  .
# 参照訳：they won by force of <UNK>  .
#
# 翻訳文：i had dinner  .
# 参照訳：i was eating dinner then  .
#
# 翻訳文：it 's hot  .
# 参照訳：it 's hot today  .
#
# 翻訳文：he is angry
# 参照訳：he is a <UNK>  .
#
# 翻訳文：he always looks around her  .
# 参照訳：he always takes sides with her  .
#
# 翻訳文：jane was always in jane  .
# 参照訳：jane always made out that she was very rich  .
#
# 翻訳文：what a bad child he is  .
# 参照訳：what a bad boy he is  !
#
# 翻訳文：he is the person when we call  .
# 参照訳：he is what we call the man of the hour  .
#
# 翻訳文：he is not a nice guy  .
# 参照訳：in fact , he is a nice fellow  .
#
# 翻訳文：where may be the answer  .
# 参照訳：where does the answer lie  ?
#
# 翻訳文：you had better prepare  .
# 参照訳：you may as well prepare for your examination  .
#
# 翻訳文：i can 't see well  .
# 参照訳：i can 't see well  .
#
# 翻訳文：can you borrow your car  ?
# 参照訳：can we rent a car  ?
#
# 翻訳文：such a man would not say  .
# 参照訳：a wise man would not say such a thing  .
#
# 翻訳文：i told her that he was ill  .
# 参照訳：he told me that she was sick  .
#
# 翻訳文：there was no garden  .
# 参照訳：there was nobody in the garden  .
#
# 翻訳文：it is far from the hotel to new station  .
# 参照訳：our college is far from the station  .
#
# 翻訳文：he kept writing  .
# 参照訳：he had been writing a letter  .
#
# 翻訳文：she has consulted him  .
# 参照訳：he spoke to her about the matter  .
#
# 翻訳文：let me have a look  .
# 参照訳：let me see it  .
#
# 翻訳文：he sat there and and sit there  .
# 参照訳：he sat there with his eyes closed  .
#
# 翻訳文：you should have worked hard  .
# 参照訳：you should work hard while you are young  .
#
# 翻訳文：he started out  .
# 参照訳：he made an abrupt departure  .
#
# 翻訳文：this is how the incident happened  .
# 参照訳：this is how the accident happened  .
#
# 翻訳文：jane was in beauty  .
# 参照訳：jane was a stewardess when she was young  .
#
# 翻訳文：he was afraid  .
# 参照訳：he was afraid of his wife  .
#
# 翻訳文：how far is to the station  ?
# 参照訳：how far is it to the station  ?
#
# 翻訳文：he is not a diligent man  .
# 参照訳：he is as diligent a man as ever lived  .
#
# 翻訳文：we must break our promise  .
# 参照訳：you should not break your promise  .
#
# 翻訳文：we want everything  .
# 参照訳：we want a house of our own  .
#
# 翻訳文：i hope you 'll take the moon  .
# 参照訳：you ask me to do the impossible  .
#
# 翻訳文：i have three times  .
# 参照訳：this baggage three times as heavy as that one  .
#
# 翻訳文：i spent a lot of time in london  .
# 参照訳：i sometimes look back on the good days i had in london  .
#
# 翻訳文：i took a taxi  .
# 参照訳：i got out of the taxi  .
#
# 翻訳文：i 'm not talking tonight  .
# 参照訳：i am due to speak tonight  .
#
# 翻訳文：the woman is very busy  .
# 参照訳：the girls are as busy as bees  .
#
# 翻訳文：we like girls to play girls  .
# 参照訳：there are more girls than boys in our school  .
#
# 翻訳文：the day is getting longer  .
# 参照訳：the days are getting longer and longer  .
#
# 翻訳文：put the table on it  .
# 参照訳：lay it on the table  .
#
# 翻訳文：what are you going to do today  ?
# 参照訳：what are you going to do today  ?
#
# 翻訳文：we had a heavy rain last night
# 参照訳：it rained hard last night  .
#
# 翻訳文：let 's go to the movies tonight  .
# 参照訳：how about going to the movies tonight  ?
#
# 翻訳文：you do not need your help  .
# 参照訳：you have no <UNK> to help us  .
#
# 翻訳文：i will go of course  .
# 参照訳：of course , i will go there with you  .
#
# 翻訳文：they went in a room  .
# 参照訳：they slept a little in the room  .
#
# 翻訳文：don 't throw away anything  .
# 参照訳：speak your mind  .
#
# 翻訳文：the old man ago  .
# 参照訳：the old man died last week  .
#
# 翻訳文：i was surprised to hear  .
# 参照訳：i was astonished to hear what had happened  .
#
# 翻訳文：he got cold  .
# 参照訳：his hands had turned blue because of the cold  .
#
# 翻訳文：i didn 't make a sense at her  .
# 参照訳：i couldn 't make her out at all  .
#
# 翻訳文：it 's my study  .
# 参照訳：it is outside my area of study  .
#
# 翻訳文：i forgot to finish your homework  .
# 参照訳：it was careless of you to forget your homework  .
#
# 翻訳文：there is a park in front  .
# 参照訳：there is a park in front of my house  .
#
# 翻訳文：i 'm not tired  .
# 参照訳：i 'm not tired at all  .
#
# 翻訳文：give me the same  .
# 参照訳：it makes no difference who i meet  .
#
# 翻訳文：she is less beautiful  .
# 参照訳：jane is no less beautiful than her mother  .
#
# 翻訳文：what on the earth is  ?
# 参照訳：what on earth is the matter  ?
#
# 翻訳文：i would like to ski  .
# 参照訳：i 'd like to go skiing with her  .
#
# 翻訳文：i don 't like english  .
# 参照訳：the mystery story is so hard that i don 't like it  .
#
# 翻訳文：she spoke well of the teacher  .
# 参照訳：her teacher praised her  .
#
# 翻訳文：here is your letter  .
# 参照訳：here is a letter for you  .
#
# 翻訳文：the word is above  .
# 参照訳：the meaning of the words is <UNK>  .
#
# 翻訳文：can speak tennis  ?
# 参照訳：speaking of sports , can you play tennis  ?
#
# 翻訳文：the price has got longer  .
# 参照訳：it 's already cleared up  .
#
# 翻訳文：i get up at six every morning  .
# 参照訳：i get up at six every morning  .
#
# 翻訳文：the bank broke away  .
# 参照訳：the bank was held up last night  .
#
# 翻訳文：i know that she was married  .
# 参照訳：i want to marry a girl like her  .
#
# 翻訳文：we told us to be quiet  .
# 参照訳：he told us to keep quiet  .
#
# 翻訳文：he is a statesman as ever lived  .
# 参照訳：he is as great a statesman as ever lived  .
#
# 翻訳文：do you look in your father  ?
# 参照訳：are you proud of your father  ?
#
# 翻訳文：the computer is able to solve  .
# 参照訳：computers can do the job with ease  .
#
# 翻訳文：that incident has something  .
# 参照訳：this case has an <UNK> with that one  .
#
# 翻訳文：there are an old tree in the tree  .
# 参照訳：there 's an old cherry tree in the garden  .
#
# 翻訳文：i like any brother  .
# 参照訳：i do not like cats and my brother does not either  .
#
# 翻訳文：my brother is out of work  .
# 参照訳：my brother has no <UNK> now  .
#
# 翻訳文：he did not so much as face  .
# 参照訳：he did not so much as turn his head  .
#
# 翻訳文：he got off at the bus stop  .
# 参照訳：he got off at the next bus stop  .
#
# 翻訳文：can 't let up what is  ?
# 参照訳：there is no telling who did this  .
#
# 翻訳文：she showed me the room  .
# 参照訳：she showed me her room  .
#
# 翻訳文：he asked me which would like  .
# 参照訳：he asked me which way to go  .
#
# 翻訳文：she is ignorant of the point  .
# 参照訳：she is anxious to know the results  .
#
# 翻訳文：the flowers are in the garden  .
# 参照訳：there are all kinds of flowers in that garden  .
#
# 翻訳文：he was on a blue coat  .
# 参照訳：he had a blue jacket on  .
#
# 翻訳文：let 's stop  .
# 参照訳：no one is coming  .
#
# 翻訳文：he has a strong mind  .
# 参照訳：he has a warm heart  .
#
# 翻訳文：she went to school the first  .
# 参照訳：she <UNK> the first day when she went to school  .
#
# 翻訳文：be careful of the future  .
# 参照訳：please take more care in the future  .
#
# 翻訳文：i had very trouble with her  .
# 参照訳：i had a lot of difficulty getting in touch with her  .
#
# 翻訳文：a policeman came at once  .
# 参照訳：the policeman 's quick arrival surprised us  .
#
# 翻訳文：please get in touch with us  .
# 参照訳：get in touch with me as soon as you arrive here  .
#
# 翻訳文：he came away from home  .
# 参照訳：it is fact that he ran away from home  .
#
# 翻訳文：she made very much  .
# 参照訳：the news made her very sad  .
#
# 翻訳文：thank you for dinner  .
# 参照訳：thank you very much for the wonderful dinner last night  .
#
# 翻訳文：i was late for ten years  .
# 参照訳：i was ten minutes late for school  .
#
# 翻訳文：how 's the weather  ?
# 参照訳：how 's the weather  ?
#
# 翻訳文：she is too hard in work  .
# 参照訳：she worked to excess  .
#
# 翻訳文：father left on the table  .
# 参照訳：father took his place at the head of the table  .
#
# 翻訳文：he is still alive
# 参照訳：he is still alive  .
#
# 翻訳文：my father ran down  .
# 参照訳：my father put a ladder against the tree  .
#
# 翻訳文：would you mind opening the door  ?
# 参照訳：would you please open the door  ?
#
# 翻訳文：he is having lunch  .
# 参照訳：i am to have lunch with him  .
#
# 翻訳文：we need a little money  .
# 参照訳：we need some money  .
#
# 翻訳文：i walk in the park  .
# 参照訳：i walk to the park  .
#
# 翻訳文：wait for me there  .
# 参照訳：just wait for me there  .
#
# 翻訳文：where did my wife  ?
# 参照訳：where 's your better half  ?
#
# 翻訳文：it is that is going to game this game  .
# 参照訳：he is likely to win this game  .
#
# 翻訳文：can you help this  .
# 参照訳：i wonder if someone could help me do this  .
#
# 翻訳文：there are any theaters in this bank  .
# 参照訳：there are many movie theaters in this city  .
#
# 翻訳文：see you again  .
# 参照訳：let 's meet here again tomorrow  .
#
# 翻訳文：if it rains , i will rain  .
# 参照訳：unless it rains , i will go , too  .
#
# 翻訳文：i like working of her  .
# 参照訳：i love this job from the bottom of my heart  .
#
# 翻訳文：this is the first time  .
# 参照訳：i 've never been to such a nice party  .
#
# 翻訳文：they did their proposal  .
# 参照訳：they <UNK> him out of school for not studying  .
#
# 翻訳文：i 'll call you back  .
# 参照訳：i 'll give you a call before i visit you  .
#
# 翻訳文：his story seems true  .
# 参照訳：his story rings true  .
#
# 翻訳文：he left a little later  .
# 参照訳：he left a while ago  .
#
# 翻訳文：what will let you mean  ?
# 参照訳：what does this kanji mean  ?
#
# 翻訳文：you must go away now  .
# 参照訳：it is necessary for you to go there immediately  .
#
# 翻訳文：i will make son  .
# 参照訳：my son shall do the work  .
#
# 翻訳文：we had a glass of wine  .
# 参照訳：i 'd like to have a glass of wine  .
#
# 翻訳文：he lived a life  .
# 参照訳：he lived a simple life  .
#
# 翻訳文：he didn 't go on a hat  .
# 参照訳：he had no hat on  .
#
# 翻訳文：my son went to america  .
# 参照訳：my son has gone to america to study medicine  .
#
# 翻訳文：i ran out of my breath  .
# 参照訳：i ran out of breath  .
#
# 翻訳文：i don 't want much to eat  .
# 参照訳：i don 't care too much for hot food  .
#
# 翻訳文：we must start at once  .
# 参照訳：we have to start at once  .
#
# 翻訳文：my number is also  .
# 参照訳：i am just a nobody  .
#
# 翻訳文：this problem is not easy  .
# 参照訳：this question isn 't easy  .
#
# 翻訳文：can go home now  ?
# 参照訳：may i go home now  ?
#
# 翻訳文：i like either  .
# 参照訳：i like both  .
#
# 翻訳文：they sat down the tree  .
# 参照訳：they sat under a tree  .
#
# 翻訳文：he has brought up  .
# 参照訳：i got some <UNK> in my eye  .
#
# 翻訳文：the old man came minutes to take  .
# 参照訳：the old man stopped for a moment to rest  .
#
# 翻訳文：how often do you visit the month  .
# 参照訳：how many times a month do you write home  ?
#
# 翻訳文：tony was not then  .
# 参照訳：tony was not busy then  .
#
# 翻訳文：are all sold down  .
# 参照訳：all sold out  !
#
# 翻訳文：it will take too within an hour  .
# 参照訳：we 'll fly there in 50 minutes  .
#
# 翻訳文：she has a student with company  .
# 参照訳：she keeps company with a foreign student  .
#
# 翻訳文：i met her by accident at the street  .
# 参照訳：yesterday i ran across her at the station  .
#
# 翻訳文：it should arrive by noon  .
# 参照訳：we should be there by noon  .
#
# 翻訳文：it was cold today  .
# 参照訳：it was colder yesterday than today  .
#
# 翻訳文：you made the same mistake  .
# 参照訳：you made the same mistake as last time  .
#
# 翻訳文：my uncle bought  .
# 参照訳：my uncle bought me this book  .
#
# 翻訳文：she was tired to go out  .
# 参照訳：being tired , she went to bed early  .
#
# 翻訳文：the weather is today  .
# 参照訳：the weather is unusual today  .
#
# 翻訳文：he is very careful  .
# 参照訳：he is being very careful  .
#
# 翻訳文：it is difficult to think  .
# 参照訳：it is hard for an old man to change his way of thinking  .
#
# 翻訳文：you had better go to bed  .
# 参照訳：you had better go to bed early  .
#
# 翻訳文：he was injured in the accident  .
# 参照訳：he was injured in the accident  .
#
# 翻訳文：the name is remember  .
# 参照訳：well do i remember the man 's name  .
#
# 翻訳文：at last they decided  .
# 参照訳：at last , they came to a decision  .
#
# 翻訳文：he is the team  .
# 参照訳：he is on the team  .
#
# 翻訳文：i 'd better give up smoking  .
# 参照訳：why don 't you give up smoking  ?
#
# 翻訳文：at the bus they were all  .
# 参照訳：they were the first to get into the bus  .
#
# 翻訳文：it 's a pity you should leave japan  .
# 参照訳：it 's a pity that you should leave japan  .
#
# 翻訳文：it is surprised to surprise  .
# 参照訳：that is surprising  .
#
# 翻訳文：we came to the town for a week  .
# 参照訳：we came to the town , where we stayed for a week  .
#
# 翻訳文：don 't touch my time  .
# 参照訳：please leave my things alone  .
#
# 翻訳文：write to me  .
# 参照訳：but you will write , won 't you  ?
#
# 翻訳文：it 's abhorrent
# 参照訳：it is still <UNK>  .
#
# 翻訳文：please turn a one  .
# 参照訳：i 'd like some more butter  .
#
# 翻訳文：that is tony  ?
# 参照訳：that boy is tony , isn 't he  ?
#
# 翻訳文：i like summer  .
# 参照訳：i like summer the best  .
#
# 翻訳文：one went through the plane  .
# 参照訳：the airplane fell to the earth  .
#
# 翻訳文：she had a pen  .
# 参照訳：she put down her pen  .
#
# 翻訳文：there was nothing in the room  .
# 参照訳：there was almost nothing in the room  .
#
# 翻訳文：i don 't think it will rain this afternoon  .
# 参照訳：i do not think it will rain this afternoon  .
#
# 翻訳文：the two are free side  .
# 参照訳：the road divides here into two  .
#
# 翻訳文：you have a genius  .
# 参照訳：you have a genius for music  .
#
# 翻訳文：she is good at skiing  .
# 参照訳：she is great at skiing  .
#
# 翻訳文：he gave out of money  .
# 参照訳：he exhausted his money  .
#
# 翻訳文：everything went well  .
# 参照訳：it all turned out for the best in the end  .
#
# 翻訳文：he gave up smoking  .
# 参照訳：he stopped smoking  .
#
# 翻訳文：he made the promise as only  .
# 参照訳：he engaged to pay the bill as soon as possible  .
#
# 翻訳文：he made up class class  .
# 参照訳：he fell behind in his english class  .
#
# 翻訳文：he came home in japan for the year  .
# 参照訳：he came back to japan for the first time in eight years  .
#
# 翻訳文：there 's a river  .
# 参照訳：there is a beautiful walk along the river  .
#
# 翻訳文：let me pay the coffee  .
# 参照訳：let me buy you a drink  .
#
# 翻訳文：i am very concerned about her
# 参照訳：i was very worried about her  .
#
# 翻訳文：almost few people know  .
# 参照訳：few people know each other well  .
#
# 翻訳文：how did the accident come  ?
# 参照訳：how did the accident come about  ?
#
# 翻訳文：when will sit up  ?
# 参照訳：what time do you leave here  ?
#
# 翻訳文：mary has a typist  .
# 参照訳：mary became a typist  .
#
# 翻訳文：father is independent of the car  .
# 参照訳：my father boasts of the fact that he has never had a traffic accident  .
#
# 翻訳文：i have made my plan  .
# 参照訳：he acquainted me with the change of the plan  .
#
# 翻訳文：sit with me  .
# 参照訳：sit down with me  .
#
# 翻訳文：express yourself  .
# 参照訳：please send the letter by express  .
#
# 翻訳文：this is a letter  .
# 参照訳：this is an important letter  .
#
# 翻訳文：take as you want  .
# 参照訳：take as many as you want  .
#
# 翻訳文：his novel is too difficult to me  .
# 参照訳：his novels are too deep for me  .
#
# 翻訳文：he is dependent on his wife  .
# 参照訳：he <UNK> on his wife <UNK>  .
#
# 翻訳文：your parents are independent of yourself  .
# 参照訳：you are old enough to be independent of your parents  .
#
# 翻訳文：we walked across the river  .
# 参照訳：we walked to the river  .
#
# 翻訳文：i made him change the plan
# 参照訳：i made him change his plan  .
#
# 翻訳文：he is the person to betray his betray  .
# 参照訳：he is the last person to betray his friends  .
#
# 翻訳文：he couldn 't travel on account  .
# 参照訳：he could not go on a trip for lack of money  .
#
# 翻訳文：i work to an hour  .
# 参照訳：i <UNK> to work for an hour  .
#
# 翻訳文：they could show them out of the afternoon  .
# 参照訳：they jumped into the water one after another  .
#
# 翻訳文：i was accustomed to air  .
# 参照訳：i was used to the heat  .
#
# 翻訳文：please call on my way  .
# 参照訳：please drop in on your way home  .
#
# 翻訳文：he gave out his trip  .
# 参照訳：he gave up going abroad  .
#
# 翻訳文：don 't forget to company  .
# 参照訳：don 't put the company in danger  .
#
# 翻訳文：someone is at the door  .
# 参照訳：someone is at the door  .
#
# 翻訳文：he has gotten into his father  .
# 参照訳：he gradually came to love his father  .
#
# 翻訳文：you could see the moon  .
# 参照訳：i saw the moon above the roof  .
#
# 翻訳文：he ought to stay home  .
# 参照訳：he is supposed to be at home today  .
#
# 翻訳文：did you practice the piano this morning  ?
# 参照訳：did you practice the piano this morning  ?
#
# 翻訳文：you should see his old house  .
# 参照訳：you must think of your old parents at home  .
#
# 翻訳文：she gave up her son mistakes  .
# 参照訳：sad to say , her son died young  .
#
# 翻訳文：if it rains tomorrow  .
# 参照訳：if it rains tomorrow , will you stay at home  ?
#
# 翻訳文：is the student  ?
# 参照訳：do you have a student fare  ?
#
# 翻訳文：let 's dinner  .
# 参照訳：let 's have dinner  .
#
# 翻訳文：do as you can get in touch with  .
# 参照訳：if something happens , feel free to call me  .
#
# 翻訳文：go on the way to go  .
# 参照訳：you need not take the trouble to go  .
#
# 翻訳文：in case , it 's your part you know it  .
# 参照訳：in any case , it 's none of your business  .
#
# 翻訳文：i think it will be three years long  .
# 参照訳：three years is a long time , i feel  .
#
# 翻訳文：could you make up the air  ?
# 参照訳：would you put on the air conditioning  ?
#
# 翻訳文：not lost my friend was  .
# 参照訳：i didn 't want to be defeated in front of my friends  .
#
# 翻訳文：please turn out the phone soon  .
# 参照訳：as soon as you get the wall painted , you can go home  .
#
# 翻訳文：i 'm very sleepy  .
# 参照訳：i 'm very sleepy now  .
#
# 翻訳文：i heard her music  .
# 参照訳：above the music , i could hear her crying  .
#
# 翻訳文：there is an accident in this meeting  .
# 参照訳：we had the meeting in this room last friday  .
#
# 翻訳文：you have only to talk down your way  .
# 参照訳：who do you want to speak to  ?
#
# 翻訳文：he has been there for two years  .
# 参照訳：his father eats there twice a week  .
#
# 翻訳文：he was poor when he was young  .
# 参照訳：he was terribly poor when he was young  .
#
# 翻訳文：you may open the window  .
# 参照訳：you may open the window  .
#
# 翻訳文：this is too danger  .
# 参照訳：driving too fast is dangerous  .
#
# 翻訳文：he has play with  .
# 参照訳：i play with him  .
#
# 翻訳文：he is a man  .
# 参照訳：i am a man  .
#
# 翻訳文：what 's your visit  ?
# 参照訳：what 's the purpose of your visit  ?
#
# 翻訳文：could you tell me the bus  .
# 参照訳：please tell me where the bus stop is  .
#
# 翻訳文：there is no way to be good  .
# 参照訳：if you must , you must  .
#
# 翻訳文：i cannot make up my decision  .
# 参照訳：i haven 't made up my mind <UNK> enough to agree with you  .
#
# 翻訳文：why did you win  ?
# 参照訳：can you account for why our team lost  ?
#
# 翻訳文：i am on sunday
# 参照訳：i 'll be on duty this sunday  .
#
# 翻訳文：it is you have a very young  .
# 参照訳：i am as much in the wrong as you are about not writing before this  .
#
# 翻訳文：they built a house of two  .
# 参照訳：it took them two years to build the house  .
#
# 翻訳文：i want to see canada  .
# 参照訳：i want to see my friends in canada  .
#
# 翻訳文：it will be necessary when you know  .
# 参照訳：i 'll let you know in advance  .
#
# 翻訳文：i thought it was done  .
# 参照訳：i thought i must do it  .
#
# 翻訳文：you don 't need time  .
# 参照訳：you should not waste your time  .
#
# 翻訳文：how a fool is  !
# 参照訳：never tell a lie  !
#
# 翻訳文：let 's carry this upstairs  .
# 参照訳：i 'll get him to carry this box upstairs  .
#
# 翻訳文：he stayed at home  .
# 参照訳：instead of going to school , he stayed at home  .
#
# 翻訳文：jim is a doctor  .
# 参照訳：jim is not a lawyer but a doctor  .
#
# 翻訳文：there are little tree  .
# 参照訳：there were few , if any , trees  .
#
# 翻訳文：where would you sit on me  ?
# 参照訳：where should i sit  ?
#
# 翻訳文：it is impossible to make my success  .
# 参照訳：the secret of success is not to think of failure  .
#
# 翻訳文：her own own own  .
# 参照訳：she goes by the name of amy  .
#
# 翻訳文：she works for the bank  .
# 参照訳：she works in a bank  .
#
# 翻訳文：can 't you put up this evening  .
# 参照訳：can you fix him up for the night  ?
#
# 翻訳文：it is known to everyone  .
# 参照訳：but his name is slightly familiar to me  .
#
# 翻訳文：i have known long  .
# 参照訳：mr smith and i have been acquainted with each other for a long time  .
#
# 翻訳文：he has experience in experience  .
# 参照訳：he has seen much of the world  .
#
# 翻訳文：if i could speak english  .
# 参照訳：i wish i could speak english  .
#
# 翻訳文：you should send a letter  .
# 参照訳：you should have replied to his letter  .
#
# 翻訳文：which do you like better ,  ?
# 参照訳：which do you like better , this or that  ?
#
# 翻訳文：she 's away for a while  .
# 参照訳：she does not take a rest for an <UNK>  .
#
# 翻訳文：he shook hands  .
# 参照訳：he shook hands with his friend  .
#
# 翻訳文：if a good rest will be nice time  .
# 参照訳：i 'll be fine if i take a little rest  .
#
# 翻訳文：i want something to new  .
# 参照訳：we want something new  .
#
# 翻訳文：he is fatter than saw  .
# 参照訳：he is fatter than when i last saw him  .
#
# 翻訳文：i have no objection to your opinion  .
# 参照訳：i do not quite agree with you  .
#
# 翻訳文：i 'll go in the class  .
# 参照訳：i 'm done with that lesson  .
#
# 翻訳文：rise is early  .
# 参照訳：early rising is good for the health  .
#
# 翻訳文：he finished this work  .
# 参照訳：he finished this work for himself  .
#
# 翻訳文：he answered my word  .
# 参照訳：his answer was to <UNK> me on the head  .
#
# 翻訳文：if you can come in my party  .
# 参照訳：if you are going to have a party , please count me in  .
#
# 翻訳文：they were at the hill  .
# 参照訳：they got to a village under a hill  .
#
# 翻訳文：english is difficult  ?
# 参照訳：english is difficult , isn 't it  ?
#
# 翻訳文：do hear you are not in talking  .
# 参照訳：speak clearly so that everyone may hear you  .
#
# 翻訳文：i don 't care that she would like  .
# 参照訳：it never occurred to me that she loved me  .
#
# 翻訳文：she is in a cold  .
# 参照訳：she is in bed with a cold  .
#
# 翻訳文：don 't be afraid of making mistakes  .
# 参照訳：don 't be afraid of making mistakes  .
#
# 翻訳文：i will never forget what she said  .
# 参照訳：i 'll never forget what you told me  .
#
# 翻訳文：he is up  .
# 参照訳：he is in service  .
#
# 翻訳文：i love him  !
# 参照訳：i really like him  !
#
# 翻訳文：swimming is a lot  .
# 参照訳：riding a horse is great fun  .
#
# 翻訳文：as i had started a walk  .
# 参照訳：it would rain just when i wanted to go out  .
#
# 翻訳文：my brother is concerned  .
# 参照訳：my sister is now bound up in her work  .
#
# 翻訳文：any work may not  .
# 参照訳：none of the telephones are working  .
#
# 翻訳文：we had baseball  .
# 参照訳：we played baseball  .
#
# 翻訳文：what is the population of tokyo  ?
# 参照訳：how large is the population of tokyo  ?
#
# 翻訳文：we were certain of the game  .
# 参照訳：we thought we had the game in the bag  .
#
# 翻訳文：i can 't agree with  .
# 参照訳：i can 't get along with that man any more  .
#
# 翻訳文：is such a face  ?
# 参照訳：can other people catch it  ?
#
# 翻訳文：she felt as also taken care  .
# 参照訳：she felt as if she had seen a ghost  .
#
# 翻訳文：this would have been done  .
# 参照訳：i might well tell you this  .
#
# 翻訳文：it came early  .
# 参照訳：<UNK> did come , but didn 't stay long  .
#
# 翻訳文：compare your tom 's address  .
# 参照訳：compare your answer with tom 's  .
#
# 翻訳文：how is that one  ?
# 参照訳：give me the <UNK> of it  .
#
# 翻訳文：i got up early this morning  .
# 参照訳：this morning i got up later than usual  .
#
# 翻訳文：this is all the whole  .
# 参照訳：this is the worst of all  .
#
# 翻訳文：shall you cook dinner for me  ?
# 参照訳：shall i cook dinner today  ?
#
# 翻訳文：he made his mind through the number  .
# 参照訳：he made his way through the crowd  .
#
# 翻訳文：can anyone hear the room  ?
# 参照訳：i can hear someone talking in the next room  .
#
# 翻訳文：what do you should write  ?
# 参照訳：where do we get the <UNK>  ?
#
# 翻訳文：she kept through the windows  .
# 参照訳：she closed all the windows in the room  .
#
# 翻訳文：i don 't like it  .
# 参照訳：i don 't like <UNK>  .
#
# 翻訳文：do you have any small change  ?
# 参照訳：do you have small change with you  ?
#
# 翻訳文：nothing is more than health  .
# 参照訳：nothing is more valuable than health  .
#
# 翻訳文：i finished reading the night  .
# 参照訳：i finished reading the book last night  .
#
# 翻訳文：your son seems to be student  .
# 参照訳：your son took part in the student movement , i hear  .
#
# 翻訳文：i am bad at sports  .
# 参照訳：i am very poor at sports  .
#
# 翻訳文：without help ,
# 参照訳：i can do without his help  .
#
# 翻訳文：you need not get up so early  .
# 参照訳：you don 't have to get up so early  .
#
# 翻訳文：he can speak english  .
# 参照訳：he can speak both english and french  .
#
# 翻訳文：it is worth saying  .
# 参照訳：if a thing is worth doing it is worth doing badly  .
#
# 翻訳文：he gave  .
# 参照訳：he gave in  .
#
# 翻訳文：i wish to  .
# 参照訳：by all means  . go ahead  .
#
# 翻訳文：she was to tears  .
# 参照訳：she tried not to shed tears  .
#
# 翻訳文：the story came home  .
# 参照訳：the story came home to her  .
#
# 翻訳文：she was satisfied with the new dress  .
# 参照訳：she was pleased with her new dress  .
#
# 翻訳文：he will take a staying in tokyo  .
# 参照訳：he will stay in tokyo for several weeks  .
#
# 翻訳文：they were busy  .
# 参照訳：they were busy  .
#
# 翻訳文：i walked to the station  .
# 参照訳：i was walking to the station then  .
#
# 翻訳文：we walked along the street  .
# 参照訳：we walked along the street  .
#
# 翻訳文：she will get this time ready  .
# 参照訳：if you telephone her again , that 'll be the last straw  !
#
# 翻訳文：an car happened  .
# 参照訳：the car accident took place just in front of me  .
#
# 翻訳文：girls are to see  .
# 参照訳：the girls are facing each other  .
#
# 翻訳文：money is not want to buy  .
# 参照訳：money cannot buy freedom  .
#
# 翻訳文：i have no homework  .
# 参照訳：i have no homework today  .
#
# 翻訳文：this coat is not old  .
# 参照訳：this old coat has had it  .
#
# 翻訳文：this box is little empty  .
# 参照訳：there is little water in the bucket  .
#
# 翻訳文：he asked for his parents to help  .
# 参照訳：when he got into trouble , he turned to his parents for help  .
#
# 翻訳文：the sun went into the clouds  .
# 参照訳：the sun went behind the clouds  .
#
# 翻訳文：his story is joke  .
# 参照訳：his talk was a mere game  .
#
# 翻訳文：that is a lie  .
# 参照訳：i dare say it is a lie  .
#
# 翻訳文：she said she was running up  .
# 参照訳：she stood up when her teacher came in  .
#
# 翻訳文：he likes it  .
# 参照訳：he likes <UNK>  .
#
# 翻訳文：the rain came  .
# 参照訳：the rain came down in buckets  .
#
# 翻訳文：please don 't come on the rain  .
# 参照訳：don 't bother coming in this rain  .
#
# 翻訳文：i will pick you up to meet  .
# 参照訳：i 'll pick you up at your home  .
#
# 翻訳文：please let me know  .
# 参照訳：let me know by wire  .
#
# 翻訳文：i 'll make this means  .
# 参照訳：i will make certain of the situation  .
#
# 翻訳文：we 'd better stay  .
# 参照訳：it 's our pleasure  .
#
# 翻訳文：i think it 's worth it  .
# 参照訳：i think it 's worth a try  .
#
# 翻訳文：he is making speech  .
# 参照訳：he is giving an address  .
#
# 翻訳文：keep your dictionary at  .
# 参照訳：always keep this dictionary handy  .
#
# 翻訳文：he will go to new york next week  .
# 参照訳：next week , he is going to new york on business  .
#
# 翻訳文：the child has gone to the mother  .
# 参照訳：the child played the baby to his mother  .
#
# 翻訳文：he tried to escape  .
# 参照訳：he tried to soothe the angry man  .
#
# 翻訳文：he thought about his book  .
# 参照訳：he wants to dispose of his books  .
#
# 翻訳文：do as i go to  .
# 参照訳：you will do exactly as i say  .
#
# 翻訳文：please take a book  .
# 参照訳：put that book aside for me  .
#
# 翻訳文：she did nothing to hear it  .
# 参照訳：when she heard it , she just cried  .
#
# 翻訳文：i have finished english  .
# 参照訳：i have just now finished doing my english homework  .
#
# 翻訳文：i will feel free my money  .
# 参照訳：i make it rule never to borrow money  .
#
# 翻訳文：ken was in japan  .
# 参照訳：ken was in japan last year  .
#
# 翻訳文：he is sick since month  .
# 参照訳：i hear he has been ill since last month  .
#
# 翻訳文：can be going to the next week  .
# 参照訳：can you sit for the exam next week  ?
#
# 翻訳文：she turned out the light  .
# 参照訳：she turned off the lights  .
#
# 翻訳文：i sometimes see him  .
# 参照訳：i meet him from time to time  .
#
# 翻訳文：i asked her if she would go to the party  .
# 参照訳：i asked her if she could go to the party  .
#
# 翻訳文：don 't eat too much  .
# 参照訳：don 't eat too much  .
#
# 翻訳文：it 's very cold  .
# 参照訳：i feel very cold  .
#
# 翻訳文：i finished the work  .
# 参照訳：i made an effort to finish my work  .
#
# 翻訳文：i want a book  .
# 参照訳：i want a book  .
#
# 翻訳文：how do you take it  .
# 参照訳：it 's touch and go  .
#
# 翻訳文：i will answer the question  .
# 参照訳：i refuse to answer the question  .
#
# 翻訳文：can you wait for a moment  ?
# 参照訳：would you mind waiting a few minutes  ?
#
# 翻訳文：i do not think that you should do  .
# 参照訳：you brought it on yourself  .
#
# 翻訳文：how long will you stay in japan  ?
# 参照訳：how long will you stay in japan  ?
#
# 翻訳文：i can solve this problem  .
# 参照訳：i can solve this problem  .
#
# 翻訳文：he asked her to go back  .
# 参照訳：she <UNK> against him  .
#
# 翻訳文：his composition has failed  .
# 参照訳：his composition was free from mistakes  .
#
# 翻訳文：we got quite to know quite a lot of our trip  .
# 参照訳：we got to know each other rather well on our recent trip  .
#
# 翻訳文：i have got in touch with him  .
# 参照訳：i want to get in touch with him  .
#
# 翻訳文：do you need there any way  ?
# 参照訳：is there any need for me to go there  ?
#
# 翻訳文：i must see  .
# 参照訳：i have no face to turn to  .
#
# 翻訳文：he was aware of the girl  .
# 参照訳：he is gone on that girl  .
#
# 翻訳文：all boys likes to play  .
# 参照訳：all boys like to play baseball  .
#
# 翻訳文：you must do  .
# 参照訳：don 't give in  .
#
# 翻訳文：i waited for my wait  .
# 参照訳：i waited and waited  .
#
# 翻訳文：illness prevented her from her  .
# 参照訳：because of illness , she couldn 't come  .
#
# 翻訳文：i have bought a plane  .
# 参照訳：i bought a watch with cash  .
#
# 翻訳文：his bicycle is blue  .
# 参照訳：his bicycle is blue  .
#
# 翻訳文：this door will not begin  .
# 参照訳：this door won 't shut  .
#
# 翻訳文：we must take this whole way  .
# 参照訳：we must take this matter into account as a whole  .
#
# 翻訳文：are you or against  .
# 参照訳：are you for the war or against it  ?
#
# 翻訳文：i will forget it  .
# 参照訳：it is probable that he forget about it  .
#
# 翻訳文：he said that the morning , took a walk  .
# 参照訳：he said that he goes for a long walk every morning  .
#
# 翻訳文：i was surprised at the news  .
# 参照訳：i was astonished at the news  .
#
# 翻訳文：how far is here from tokyo  ?
# 参照訳：how far is it from here to tokyo  ?
#
# 翻訳文：would you mind my mind  ?
# 参照訳：sorry , i wish you wouldn 't  .
#
# 翻訳文：this train has arrived at airport  .
# 参照訳：i arrived at narita airport this morning  .
#
# 翻訳文：he promised not to give  .
# 参照訳：he promised not to tell  .
#
# 翻訳文：he looks young for his age  .
# 参照訳：he looks young considering his age  .
#
# 翻訳文：i made them go there  .
# 参照訳：they made me go there alone  .
#
# 翻訳文：please tell me  .
# 参照訳：let me know the <UNK>  .
#
# 翻訳文：you are right  .
# 参照訳：you are absolutely right  .
#
# 翻訳文：he has finished the work  .
# 参照訳：his work finished , he went to bed  .
#
# 翻訳文：my sister washes every hair  .
# 参照訳：my sister washes her hair every morning  .
#
# 翻訳文：please put down  .
# 参照訳：please give me help in taking this down  .
#
# 翻訳文：i don 't like him  .
# 参照訳：i do not care for him  .
#
# 翻訳文：it has never done  .
# 参照訳：nothing can be better than that  .
#
# 翻訳文：in the time , will you do  .
# 参照訳：this will do for now  .
#
# 翻訳文：i didn 't see today  .
# 参照訳：i hope it will be the only one  .
#
# 翻訳文：she has a son  .
# 参照訳：she has a son who is a doctor  .
#
# 翻訳文：the teacher looked over  .
# 参照訳：the teacher looked over the examination papers  .
#
# 翻訳文：he was in time for the train  .
# 参照訳：he had the luck to catch the train  .
#
# 翻訳文：i walk
# 参照訳：i will go on foot  .
#
# 翻訳文：she was late with me  .
# 参照訳：she was sore at me for being late  .
#
# 翻訳文：it 's better not to do  .
# 参照訳：i 'd better not eat that  .
#
# 翻訳文：i am willing to help you
# 参照訳：i will <UNK> help you  .
#
# 翻訳文：i went fishing yesterday  .
# 参照訳：i went fishing in the river yesterday  .
#
# 翻訳文：i have been to the station  .
# 参照訳：i have been to the station  .
#
# 翻訳文：he gave some box  .
# 参照訳：he put some coins in the box  .
#
# 翻訳文：this is a book  .
# 参照訳：this is a book  .
#
# 翻訳文：he left the clothes  .
# 参照訳：he had the table to himself  .
#
# 翻訳文：it was before i left off  .
# 参照訳：i reached school before the rain started  .
#
# 翻訳文：the war was out of the war  .
# 参照訳：the country was <UNK> up for war  .
#
# 翻訳文：i know this song  .
# 参照訳：this song is familiar to me  .
#
# 翻訳文：you could find the right time  .
# 参照訳：time will tell which is right  .
#
# 翻訳文：did you clean your room
# 参照訳：did you clean your room  ?
#
# 翻訳文：he is good at tennis  .
# 参照訳：he is good at tennis  .
#
# 翻訳文：he is not one of love  .
# 参照訳：he is the last person to speak ill of others  .
#
# 翻訳文：take a map  .
# 参照訳：may i have a road map  ?
#
# 翻訳文：what he says does not understand  .
# 参照訳：i cannot make anything of what he says  .
#
# 翻訳文：it 's used to order to get up  .
# 参照訳：it took a long time to accustom myself to the noise  .
#
# 翻訳文：you ought not to say such a thing  .
# 参照訳：you ought not to say such a thing  .
#
# 翻訳文：what a good book this is  .
# 参照訳：what good books these are  .
#
# 翻訳文：his success was due to success  .
# 参照訳：for all his efforts , he didn 't succeed  .
#
# 翻訳文：where are you from  ?
# 参照訳：where do you come from  ?
